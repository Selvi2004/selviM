# %% [markdown]
# Python Assignment - II

# %% [markdown]
# Inheritance and Its types

# %% [markdown]
# Single Inheritance

# %%
class base(object): 
       
    # Constructor 
    def __init__(fly, value1,value2): 
        fly.value1 = value1 
        fly.value2 = value2
   
    # To perform addition
    def Addition(fly) : 
        print(" value1 : " , fly.value1)
        print(" value2 : " , fly.value2)
        return fly.value1 + fly.value2
              
# derived class or the sub class
class Derived(base): 
    
    #function to perform addition
   def subraction(fly) :
        print(" value1 : " , fly.value1)
        print(" value2 : " , fly.value2)
        return fly.value1 - fly.value2
      
# Driver code 
Obj = Child_class(10,15)  # parent class object
print(" Added value :" , Obj.Addition() ) 
print( " " )
Obj1 = Child_class(50,30)  # parent class object
print("Subracted value :" , Obj1.subraction() )
# Out:
#  value1 :  10
#  value2 :  15
#  Added value : 25
#
#  value1 :  50
#  value2 :  30
# Subracted value : 20

# %% [markdown]
# MULTIPLE INHERITANCE

# %%
class Mother:
    mothername = ""
 
    def mother(self):
        print(self.mothername)
 
 
class Father:
    fathername = ""
 
    def father(self):
        print(self.fathername)
 
 
class Son(Mother, Father):
    def parents(self):
        print("Father Name :", self.fathername)
        print("Mother  Name:", self.mothername)
 
 
# Driver's code
s1 = Son()
s1.fathername = "Murugan"
s1.mothername = "Visalatchi"
s1.parents()
# Out:
# Father Name : Murugan
# Mother  Name: Visalatchi

# %% [markdown]
# MULTILEVEL INHERITANCE

# %%
class Animal:  
    def speak(self):  
        print("Animal Speaking")  
 
class Dog(Animal):  
    def bark(self):  
        print("dog barking")  
  
class DogChild(Dog):  
    def eat(self):  
        print("Eating bread...")  
d = DogChild()  
d.bark()  
d.speak()  
d.eat()
# Out:
# dog barking
# Animal Speaking
# Eating bread...

# %% [markdown]
# HYBRID INHERITANCE

# %%
class home:
    def func1(self):
        print("This function is in home.")
 
 
class school(home):
    def func2(self):
        print("This function is in school. ")
 
 
class tuition(home):
    def func3(self):
        print("This function is in tuition.")
 
 
class playground(school, home):
    def func4(self):
        print("This function is in playground🤩.")
 
obj = child()
obj.func1()
obj.func2()
# Out:
# This function is in home.
# This function is in school.

# %% [markdown]
# HIERARCHICAL INHERITANCE

# %%
class Parent:
    def func1(self):
        print("This function is in parent class.")
 
 
class Child1(Parent):
    def func2(self):
        print("This function is in child 1.")
 
 
class Child2(Parent):
    def func3(self):
        print("This function is in child 2.")
 
object1 = Child1()
object2 = Child2()
object1.func1()
object1.func2()
object2.func1()
object2.func3()
# Out:
# This function is in parent class.
# This function is in child 1.
# This function is in parent class.
# This function is in child 2.

# %% [markdown]
# EXCEPTION HANDLING

# %% [markdown]
# ZerroDivisonal error

# %%
def fun(a):
    if a < 4:
        b = a/(a-3)
    print("Value of b = ", b) 
try:
    fun(3)
    fun(5)
  
 
# multiple exceptions
except ZeroDivisionError:
    print("ZeroDivisionError Occurred and Handled")
# Out:
# ZeroDivisionError Occurred and Handled

# %% [markdown]
# TAB ERROR

# %%
a = [1, 2, 3]
try: 
    print ("Second element = %d" %(a[1]))
  
    # Throws error since there are only 3 elements in array
    print ("Fourth element = %d" %(a[3]))
  
except:
    print ("An error occurred")
# Out:
# Second element = 2
# An error occurred

# %% [markdown]
# VALUE ERROR

# %%
while True:
...     try:
...         x = int(input("Please enter a number: "))
...         break
...     except ValueError:
...         print("Oops!  That was no valid number.  Try again...")
...
# Out:
# Please enter a number: 788

# %% [markdown]
#  FILE OPENING ERROR

# %%
try:
  f = open("demofile.txt")
  try:
    f.write("Lorum Ipsum")
  except:
    print("Something went wrong when writing to the file")
  finally:
    f.close()
except:
  print("Something went wrong when opening the file")
# Out:
# Something went wrong when opening the file

# %% [markdown]
# INDENTATION ERROR

# %%
a = 10
try:
     b = 19
     c = a+b
except:
    print("indentation error is occured")
print(c)
# Out:
# 29

# %% [markdown]
# NAME ERROR

# %%
try:
  print(s)
except NameError:
  print("Variable s is not defined")
except:
  print("Something else went wrong")
# Out:
# Variable s is not defined

# %% [markdown]
#                                             REGULAR EXPRESSION

# %% [markdown]
# FINDALL()

# %%
import re

word = "python is a interrepted language"
x = re.findall("is", word)
print(x)
# Out:
# ['is']

# %% [markdown]
# SEARCH()

# %%
import re

fly = "This is beautiful world "
x = re.search("\s", fly)

print("The located in position:", x.start())
# Out:
# The located in position: 4

# %% [markdown]
# SPLIT()

# %%
import re

sen = "PYTHON IS A INTEREPTED LANGUAGE"
x = re.split("\s", sen)
print(x)
# Out:
# ['PYTHON', 'IS', 'A', 'INTEREPTED', 'LANGUAGE']

# %% [markdown]
# SUB()

# %%
import re
part = "PYTHON IS A INTEREPTED LANGUAGE"
x = re.sub("\s", "n", part)
print(x)
# Out:
# PYTHONnISnAnINTEREPTEDnLANGUAGE

# %% [markdown]
#                                             AGRREGATE FUNCTIONS

# %%
import numpy as np
arr1 = np.array([10,20,30,40,50])
arr1
b = np.array([20,34,45,56,78])
print(b)
# Out:
# [20 34 45 56 78]

# %%
FLY = np.array([[0,10,20],[3,4,50],[90,40,50]])
FLY
# Out:
# array([[ 0, 10, 20],
#        [ 3,  4, 50],
#        [90, 40, 50]])

# %% [markdown]
# SUM FUNCTION

# %%
arr1.sum()
# Out:
# 150

# %%
FLY.sum(axis=0)
# Out:
# array([ 93,  54, 120])

# %%
FLY.sum(axis=1)
# Out:
# array([ 30,  57, 180])

# %% [markdown]
# PRODUCT FUNCTION

# %%
np.prod(arr1)
# Out:
# 12000000

# %%
np.prod(FLY,axis=0)
# Out:
# array([    0,  1600, 50000])

# %%
np.prod(FLY,axis=1)
# Out:
# array([     0,    600, 180000])

# %% [markdown]
# AVERAGE FUNCTION

# %%
np.average(FLY,axis = 1)
# Out:
# array([10., 19., 60.])

# %%
np.average(FLY,axis = 0)
# Out:
# array([31., 18., 40.])

# %% [markdown]
# MINIMUM FUNCTION

# %%
FLY.min(axis = 0)
# Out:
# array([ 0,  4, 20])

# %%
FLY.min(axis = 1)
# Out:
# array([ 0,  3, 40])

# %% [markdown]
# MAXIMUM FUNCTION

# %%
FLY.max(axis = 0)
# Out:
# array([90, 40, 50])

# %%
FLY.max(axis = 1)
# Out:
# array([20, 50, 90])

# %%
import numpy as np
x = np.random.randint(1, 10, size = (5, 5))
print(x)
print()
 
y = np.random.randint(1, 10, size = (5, 5))
print(y)
 
print('\nMinimum Array')
print(np.minimum(x, y))
# Out:
# [[7 7 7 9 6]
#  [6 5 8 5 4]
#  [8 4 6 6 1]
#  [8 5 6 5 4]
#  [1 3 5 2 6]]
#
# [[9 8 2 1 8]
#  [6 5 7 1 6]
#  [3 4 9 2 8]
#  [3 2 8 5 9]
#  [6 8 4 4 7]]
#
# Minimum Array
# [[7 7 2 1 6]
#  [6 5 7 1 4]
#  [3 4 6 2 1]
#  [3 2 6 5 4]
#  [1 3 4 2 6]]

# %%
import numpy as np
 
a = np.array([1, 20, 5, 22, 8, 15])
print(a)

b = np.array([12, 9, 3, 42, 6, 33])
print(b)
 
print('\nMaximum Array')
print(np.maximum(a, b))
# Out:
# [ 1 20  5 22  8 15]
# [12  9  3 42  6 33]
#
# Maximum Array
# [12 20  5 42  8 33]

# %% [markdown]
# MEDIAN FUNCTION

# %%
np.median(FLY)
np.median(FLY)

np.median(FLY, axis = 0)
np.median(FLY, axis = 1)
# Out:
# array([10.,  4., 50.])

# %% [markdown]
# VARIANCE FUNCTION

# %%
arr1.var()
FLY.var()


x.var()
y.var()
# Out:
# 6.8

# %% [markdown]
# CUMULATIVE SUM

# %%
arr1.cumsum()
arr2.cumsum()
# Out:
# array([  0,  10,  30,  50,  90, 140, 170, 210, 260], dtype=int32)

# %% [markdown]
# CUMULATIVE PRODUCT

# %%
arr1.cumprod()
FLY.cumprod()
 

# Let me find the cumulative product of array elements in x and Y axis
FLY.cumprod(axis = 0)
FLY.cumprod(axis = 1)
# Out:
# array([[     0,      0,      0],
#        [     3,     12,    600],
#        [    90,   3600, 180000]], dtype=int32)

# %% [markdown]
# PERCENTILE FUNCTION

# %%
np.percentile(FLY, 10)
np.percentile(FLY, 30)
np.percentile(FLY, 50)
np.percentile(FLY, 75)
np.percentile(FLY, 100)
# Out:
# 90.0

# %% [markdown]
# ARGMIN FUNCTION

# %%
arr4 = np.random.randint(10, size = (9))
arr4

arr5 = np.random.randint(8, size = (5, 5))
arr5
# Out:
# array([[4, 1, 3, 7, 3],
#        [4, 5, 1, 4, 4],
#        [5, 6, 3, 2, 6],
#        [0, 0, 1, 1, 2],
#        [3, 2, 6, 5, 7]])
